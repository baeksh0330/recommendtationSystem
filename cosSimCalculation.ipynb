# %%
import pandas as pd
import numpy as np

games = pd.read_csv('C:/MachineLearning TP/recommendtationSystem/game dataset/games_preprocessing.csv')

# %%
games = games.reset_index(drop=False)
games.head()
# Out:
#    index  Unnamed: 0  app_id                        title  date_release  win
# 0      0       15005  282010         Carmageddon Max Pack          1997    1  \
# 1      1       31261  232770                       POSTAL          1997    1
# 2      2       47376      70                    Half-Life          1998    1
# 3      3       34507  224920  Legacy of Kain: Soul Reaver          1999    1
# 4      4        8617      20        Team Fortress Classic          1999    1
#
#    mac  linux  rating  positive_ratio  user_reviews  price_final
# 0    0      0      90              85           428         9.99  \
# 1    1      1      90              85          2329         0.00
# 2    1      1      95              96         72475         9.99
# 3    0      0      80              73          1467         0.00
# 4    1      1      90              85          5146         4.99
#
#    price_original  discount  steam_deck
# 0            9.99       0.0           1
# ...

# %%
title = games['title']
games2 = games.drop('title', axis=1)
item_sim = games2.dot(games2.T) / np.linalg.norm(games2, axis=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\MachineLearning TP\recommendtationSystem\cosSimCalculation.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/MachineLearning%20TP/recommendtationSystem/cosSimCalculation.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> title = games['title']
#       <a href='vscode-notebook-cell:/c%3A/MachineLearning%20TP/recommendtationSystem/cosSimCalculation.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> games2 = games.drop('title', axis=1)
# ----> <a href='vscode-notebook-cell:/c%3A/MachineLearning%20TP/recommendtationSystem/cosSimCalculation.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> item_sim = games2.dot(games2.T) / np.linalg.norm(games2, axis=1)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
# ...

# %%
item_sim.head()
# item_sim.to_csv('item_similarity.csv')
# Out:
#            0              1             2              3             4
# 0  282416.318304  281495.135320   8840.229265  281027.648235  13791.359359  \
# 1  234113.735176  234879.864186  19283.390867  234837.244912  28337.750062
# 2    2711.046593    7110.511737  86609.043117    7737.904678  76721.342478
# 3  226446.192646  227523.861891  20331.334993  227565.153901  30622.172098
# 4     499.787702    1234.775080   9066.115147    1377.204742  10234.538817
#
#           5             6             7             8             9      ...
# 0  10182.336728   5383.294853  15910.834670  13967.622514  16113.328104  ...  \
# 1  21106.582121  12517.964434  31931.851555  26890.272919  31795.328390  ...
# 2  86126.494898  84040.189455  60752.526166  83109.274838  59821.699018  ...
# 3  22298.509412  12770.279966  34890.930891  28670.181702  34693.926732  ...
# 4   9411.054826   7719.605176   9643.153516  10035.613129   9679.558553  ...
#
# ...

# %%
games.head()
# Out:
#    index  Unnamed: 0  app_id                        title  date_release  win
# 0      0       15005  282010         Carmageddon Max Pack          1997    1  \
# 1      1       31261  232770                       POSTAL          1997    1
# 2      2       47376      70                    Half-Life          1998    1
# 3      3       34507  224920  Legacy of Kain: Soul Reaver          1999    1
# 4      4        8617      20        Team Fortress Classic          1999    1
#
#    mac  linux  rating  positive_ratio  user_reviews  price_final
# 0    0      0      90              85           428         9.99  \
# 1    1      1      90              85          2329         0.00
# 2    1      1      95              96         72475         9.99
# 3    0      0      80              73          1467         0.00
# 4    1      1      90              85          5146         4.99
#
#    price_original  discount  steam_deck
# 0            9.99       0.0           1
# ...

# %%
def cosSim_get_similar_games(game_id, item_sim, games):
  target_row = games.loc[games["app_id"] == game_id]

  target_row_index = target_row.index[0]

  target_row_sim = item_sim[target_row_index]

  top_3_indices = target_row_sim.argsort()[-4:][::-1]

  return games.iloc[top_3_indices][1:]

# 선호 표현 게임 아이디
game_id = 2599300
games[games['app_id']==game_id] # 주어진 게임(선호 게임)
# Out:
#        index  Unnamed: 0   app_id        title  date_release  win  mac  linux
# 47499  47499       17243  2599300  Dead Signal          2023    1    0      0  \
#
#        rating  positive_ratio  user_reviews  price_final  price_original
# 47499      90              92           138          8.0             0.0  \
#
#        discount  steam_deck
# 47499       0.0           1

# %%
cosSim_get_similar_games(game_id, item_sim, games).head() # 유사도 상위 3개 게임, 순서 바꿔서 해도 결과 유사
# Out:
#        index  Unnamed: 0   app_id
# 48367  48367       17142  2593020  \
# 47526  47526       17240  2585640
# 48596  48596       17131  2585630
#
#                                                    title  date_release  win
# 48367           NARAKA: BLADEPOINT - Pioneer Season Pack          2023    1  \
# 47526  Warhammer: Vermintide 2 - Necromancer Cosmetic...          2023    1
# 48596       Warhammer: Vermintide 2 - Necromancer Career          2023    1
#
#        mac  linux  rating  positive_ratio  user_reviews  price_final
# 48367    0      0      50              43            57         15.0  \
# 47526    0      0      80              78            37          0.0
# 48596    0      0      90              92            69          4.0
#
#        price_original  discount  steam_deck
# 48367             0.0       0.0           1
# 47526             0.0       0.0           1
# 48596             0.0       0.0           1
